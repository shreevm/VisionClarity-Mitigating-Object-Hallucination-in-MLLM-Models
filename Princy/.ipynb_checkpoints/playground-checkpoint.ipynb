# %%
# VISION CLARITY

# %% [markdown]
# # HW1
# ### data exploration & visualization

# %%
# import necessary libraries 
import os
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline 
import pandas as pd

# %%
#as of now 
#set the path to the datset folder 

dataset_path = r'C:\Users\Shree\Documents\VisionClarity-Mitigating-Object-Hallucination-in-MLLM-Models\Shree\Images'

# %%
# Check if the path exists
if not os.path.exists(dataset_path):
    print(f"Error: The dataset path '{dataset_path}' does not exist.")
else:
    # Get a list of all folders in the dataset directory
    folders_list = os.listdir(dataset_path)

# %%
folders_list
# Out:
# ['color',
#  'counting',
#  'existence',
#  'OCR',
#  'orientation',
#  'position',
#  'shape',
#  'size']

# %%
#To store the count of images in each folder 
image_counts={}

#iterate through each folder and count the images 
for folder in folders_list:
    folder_path=os.path.join(dataset_path,folder)
    if os.path.exists(folder_path):
        #count the no.of images in the folder 
        image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))] #to match to the different file  types 
        image_counts[folder] = len(image_files)
    else:
        image_counts[folder] = 0  # If folder does not exist,count=0

# %%
# Display the counts of images in each folder
for folder, count in image_counts.items():
    print(f"Number of images in '{folder}' folder : {count}")
# Out:
# Number of images in 'color' folder : 72
# Number of images in 'counting' folder : 82
# Number of images in 'existence' folder : 102
# Number of images in 'OCR' folder : 68
# Number of images in 'orientation' folder : 94
# Number of images in 'position' folder : 52
# Number of images in 'shape' folder : 74
# Number of images in 'size' folder : 106

# %%
#to display the size,dimensions,file_type and file_name of each images in the folders 

image_info={}
for folder in folders_list:
    folder_path = os.path.join(dataset_path, folder)
    
    if os.path.exists(folder_path):
        # Initialize variables for file size and image count
        total_size = 0
        image_files = []
        
        # Count the number of image files and calculate their sizes
        for img_name in os.listdir(folder_path):
            if img_name.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp')):
                img_path = os.path.join(folder_path, img_name)
                
                # Get file size
                total_size += os.path.getsize(img_path)
                
                # Store image details
                with Image.open(img_path) as img:
                    image_files.append({
                        'name': img_name,
                        'size': os.path.getsize(img_path),
                        'type': img.format,
                        'dimensions': img.size
                    })
        
        # Store information for the current folder
        image_info[folder] = {
            'total_images': len(image_files),
            'total_size_bytes': total_size,
            'image_details': image_files
        }
    else:
        image_info[folder] = {
            'total_images': 0,
            'total_size_bytes': 0,
            'image_details': []
        }  # If folder does not exist

# Display the results
for folder, info in image_info.items():
    print(f"\nFolder_Name: '{folder}'")
    print(f"  Number of images: {info['total_images']}")
    print(f"  Total size (bytes): {info['total_size_bytes']}\n")
    
    # Display details of each image
    for detail in info['image_details']:
        print(f"    - {detail['name']}: {detail['size']} bytes, Type: {detail['type']}, Dimensions: {detail['dimensions']}")
# Out:
# Folder_Name: 'color'
#   Number of images: 72
#   Total size (bytes): 157734416
#
#     - color_0.png: 1975748 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_1.png: 2429903 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_10.png: 1591817 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_11.png: 2426366 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_12.png: 2468688 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_13.png: 1939528 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_14.png: 2865387 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_15.png: 1937006 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_16.png: 2644965 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_17.png: 2240694 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_18.png: 2468501 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_19.png: 2388096 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_2.png: 2358114 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_20.png: 2522256 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_21.png: 2376500 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_22.png: 2514803 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_23.png: 2716212 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_24.png: 2424443 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_25.png: 2480658 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_26.png: 2142424 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_27.png: 2062326 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_28.png: 2657186 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_29.png: 2696667 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_3.png: 1830663 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_30.png: 2356768 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_31.png: 1329201 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_32.png: 2527136 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_33.png: 2253918 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_34.png: 2172052 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_35.png: 2501973 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_36.png: 2226400 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_37.png: 2330599 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_38.png: 2268211 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_39.png: 2328065 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_4.png: 1916697 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_40.png: 2291436 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_41.png: 2329899 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_42.png: 2237741 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_43.png: 1509696 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_44.png: 1458160 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_45.png: 2421384 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_46.png: 2589521 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_47.png: 2538436 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_48.png: 1053243 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_49.png: 2043955 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_5.png: 1760077 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_50.png: 2101646 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_51.png: 2180883 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_52.png: 1718553 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_53.png: 1866394 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_54.png: 1982973 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_55.png: 2017182 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_56.png: 2139368 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_57.png: 2401635 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_58.png: 2008686 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_59.png: 1933397 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_6.png: 2583689 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_60.png: 2218268 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_61.png: 2047069 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_62.png: 2207051 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_63.png: 2093835 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_64.png: 2180159 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_65.png: 2126891 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_66.png: 2060063 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_67.png: 2066951 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_68.png: 2236038 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_69.png: 2307461 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_7.png: 2472496 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_70.png: 1852580 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_71.png: 2196295 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_8.png: 2415469 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - color_9.png: 1715865 bytes, Type: PNG, Dimensions: (1024, 1024)
#
# Folder_Name: 'counting'
#   Number of images: 82
#   Total size (bytes): 180063915
#
#     - counting_0.png: 2211716 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_1.png: 2043897 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_10.png: 2924833 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_11.png: 2383941 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_12.png: 2646809 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_13.png: 2495613 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_14.png: 2604709 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_15.png: 2265034 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_16.png: 2629381 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_17.png: 2701000 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_18.png: 2631763 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_19.png: 2234510 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_2.png: 2287929 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_20.png: 1479797 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_21.png: 2501299 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_22.png: 1545804 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_23.png: 1806799 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_24.png: 1698865 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_25.png: 2443064 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_26.png: 2060962 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_27.png: 2207162 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_28.png: 2079580 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_29.png: 2515140 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_3.png: 1878824 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_30.png: 2215935 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_31.png: 2545657 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_32.png: 1936170 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_33.png: 2422665 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_34.png: 1800946 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_35.png: 1519784 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_36.png: 2393996 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_37.png: 2462201 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_38.png: 2467442 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_39.png: 1757743 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_4.png: 1927769 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_40.png: 2017898 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_41.png: 2218838 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_42.png: 2082753 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_43.png: 1443703 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_44.png: 1972925 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_45.png: 1455384 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_46.png: 2076538 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_47.png: 2010682 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_48.png: 2109033 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_49.png: 2432547 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_5.png: 2081619 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_50.png: 2472460 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_51.png: 2434663 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_52.png: 2564802 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_53.png: 2085466 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_54.png: 2265190 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_55.png: 2585018 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_56.png: 2264818 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_57.png: 2560411 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_58.png: 2675321 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_59.png: 2693532 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_6.png: 1926347 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_60.png: 2116957 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_61.png: 1701581 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_62.png: 2100919 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_63.png: 2534021 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_64.png: 2115631 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_65.png: 2049334 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_66.png: 2103353 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_67.png: 2080212 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_68.png: 1893490 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_69.png: 1858670 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_7.png: 2782140 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_70.png: 1853007 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_71.png: 2017266 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_72.png: 1729649 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_73.png: 2682889 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_74.png: 2685881 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_75.png: 2621145 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_76.png: 2086949 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_77.png: 2244392 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_78.png: 2139027 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_79.png: 2284910 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_8.png: 2564361 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_80.png: 1185170 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_81.png: 1710881 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - counting_9.png: 2763393 bytes, Type: PNG, Dimensions: (1024, 1024)
#
# Folder_Name: 'existence'
#   Number of images: 102
#   Total size (bytes): 189542522
#
#     - existence_0.png: 2235558 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_1.png: 1317823 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_10.png: 1544322 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_100.png: 2117874 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_101.png: 1653090 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_11.png: 1521856 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_12.png: 1448279 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_13.png: 1658033 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_14.png: 2314209 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_15.png: 1438052 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_16.png: 1436252 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_17.png: 1428455 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_18.png: 1638994 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_19.png: 1575906 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_2.png: 1829675 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_20.png: 1697876 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_21.png: 2086296 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_22.png: 1877443 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_23.png: 2009232 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_24.png: 2039285 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_25.png: 1904608 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_26.png: 1798963 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_27.png: 2050096 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_28.png: 1958384 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_29.png: 1585872 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_3.png: 1517456 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_30.png: 1553246 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_31.png: 1892175 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_32.png: 1949143 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_33.png: 1459111 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_34.png: 1344937 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_35.png: 1432550 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_36.png: 1603915 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_37.png: 1332373 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_38.png: 2190758 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_39.png: 2165402 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_4.png: 1207394 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_40.png: 2120639 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_41.png: 1639379 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_42.png: 2222210 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_43.png: 2293238 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_44.png: 2680151 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_45.png: 1714094 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_46.png: 1418899 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_47.png: 2208993 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_48.png: 1898871 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_49.png: 1300916 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_5.png: 1586333 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_50.png: 2091653 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_51.png: 1932644 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_52.png: 2014175 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_53.png: 2301413 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_54.png: 1841400 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_55.png: 2143676 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_56.png: 1427220 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_57.png: 2128555 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_58.png: 1299096 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_59.png: 1234653 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_6.png: 2057672 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_60.png: 1310929 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_61.png: 1698077 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_62.png: 1689343 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_63.png: 1203997 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_64.png: 1949999 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_65.png: 2013979 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_66.png: 2426623 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_67.png: 2787081 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_68.png: 2565214 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_69.png: 1966929 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_7.png: 2147001 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_70.png: 1920740 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_71.png: 1944966 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_72.png: 2585175 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_73.png: 2166113 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_74.png: 1853247 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_75.png: 1708463 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_76.png: 2336810 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_77.png: 2142069 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_78.png: 2232890 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_79.png: 1890317 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_8.png: 1545120 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_80.png: 2126810 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_81.png: 2212630 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_82.png: 2208372 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_83.png: 2050877 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_84.png: 2053106 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_85.png: 1693186 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_86.png: 1877841 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_87.png: 1861189 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_88.png: 1762856 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_89.png: 2132910 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_9.png: 2630729 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_90.png: 2067993 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_91.png: 2061519 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_92.png: 1954649 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_93.png: 1450727 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_94.png: 1516615 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_95.png: 1158890 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_96.png: 1195625 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_97.png: 1977405 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_98.png: 1920992 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - existence_99.png: 2171746 bytes, Type: PNG, Dimensions: (1024, 1024)
#
# Folder_Name: 'OCR'
#   Number of images: 68
#   Total size (bytes): 139167720
#
#     - OCR_0.png: 2146935 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_1.png: 2114352 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_10.png: 2264546 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_11.png: 2393210 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_12.png: 1841806 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_13.png: 1981010 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_14.png: 1801729 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_15.png: 2287173 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_16.png: 1704326 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_17.png: 1818128 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_18.png: 2334655 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_19.png: 2336808 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_2.png: 2343639 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_20.png: 1835179 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_21.png: 1957730 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_22.png: 1657282 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_23.png: 1978058 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_24.png: 1728694 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_25.png: 2204065 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_26.png: 2088589 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_27.png: 1947640 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_28.png: 1739420 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_29.png: 1961401 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_3.png: 2535787 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_30.png: 2034076 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_31.png: 1961026 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_32.png: 2105038 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_33.png: 2156826 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_34.png: 2239309 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_35.png: 2069260 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_36.png: 1900212 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_37.png: 1839928 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_38.png: 2318901 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_39.png: 1749858 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_4.png: 2130089 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_40.png: 1649428 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_41.png: 2037506 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_42.png: 2065132 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_43.png: 2547797 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_44.png: 1883546 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_45.png: 2229085 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_46.png: 2066149 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_47.png: 2267835 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_48.png: 1651766 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_49.png: 2050417 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_5.png: 2054124 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_50.png: 2087338 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_51.png: 1910669 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_52.png: 1770947 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_53.png: 2214738 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_54.png: 2028350 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_55.png: 2305639 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_56.png: 1962317 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_57.png: 1991641 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_58.png: 1925126 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_59.png: 1951799 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_6.png: 2051412 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_60.png: 2408657 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_61.png: 2364308 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_62.png: 2353701 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_63.png: 2072250 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_64.png: 1867354 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_65.png: 2014804 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_66.png: 1989110 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_67.png: 1699666 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_7.png: 1922698 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_8.png: 2322210 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - OCR_9.png: 1943516 bytes, Type: PNG, Dimensions: (1024, 1024)
#
# Folder_Name: 'orientation'
#   Number of images: 94
#   Total size (bytes): 216619548
#
#     - orientation_0.png: 2149913 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_1.png: 2239645 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_10.png: 2042764 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_11.png: 2438271 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_12.png: 2353000 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_13.png: 2637118 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_14.png: 1746010 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_15.png: 1396381 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_16.png: 1676371 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_17.png: 1251725 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_18.png: 1468636 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_19.png: 1218725 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_2.png: 2624611 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_20.png: 2332457 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_21.png: 2394641 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_22.png: 2752863 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_23.png: 2630060 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_24.png: 2871174 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_25.png: 2446525 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_26.png: 2316283 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_27.png: 2311874 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_28.png: 2268616 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_29.png: 2449504 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_3.png: 2611655 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_30.png: 2311143 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_31.png: 2020961 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_32.png: 2379598 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_33.png: 2279591 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_34.png: 2256132 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_35.png: 2395050 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_36.png: 1789108 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_37.png: 2481606 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_38.png: 2280910 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_39.png: 1761629 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_4.png: 2374653 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_40.png: 2362804 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_41.png: 2568263 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_42.png: 2244690 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_43.png: 2358081 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_44.png: 2401616 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_45.png: 2320086 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_46.png: 2356352 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_47.png: 2430109 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_48.png: 2571076 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_49.png: 2376994 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_5.png: 2963698 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_50.png: 2261125 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_51.png: 2072398 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_52.png: 2397762 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_53.png: 2380617 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_54.png: 2200182 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_55.png: 2130032 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_56.png: 2072264 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_57.png: 2342536 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_58.png: 2198422 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_59.png: 1992334 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_6.png: 2739775 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_60.png: 2288940 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_61.png: 2446419 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_62.png: 2343225 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_63.png: 2620047 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_64.png: 2418805 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_65.png: 2334211 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_66.png: 2359244 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_67.png: 2542420 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_68.png: 2380266 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_69.png: 2603531 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_7.png: 2316500 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_70.png: 2507286 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_71.png: 2342302 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_72.png: 2376781 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_73.png: 2335133 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_74.png: 1987841 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_75.png: 2477697 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_76.png: 2485493 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_77.png: 2324026 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_78.png: 2319849 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_79.png: 1921352 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_8.png: 2460396 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_80.png: 2781890 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_81.png: 2563273 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_82.png: 2461373 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_83.png: 2703445 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_84.png: 2575260 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_85.png: 2618504 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_86.png: 2533720 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_87.png: 2479126 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_88.png: 2237165 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_89.png: 2590053 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_9.png: 1960891 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_90.png: 1435617 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_91.png: 2235069 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_92.png: 2673729 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - orientation_93.png: 1878250 bytes, Type: PNG, Dimensions: (1024, 1024)
#
# Folder_Name: 'position'
#   Number of images: 52
#   Total size (bytes): 107266721
#
#     - position_0.png: 2310074 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_1.png: 2144481 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_10.png: 1689982 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_11.png: 2367612 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_12.png: 2413542 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_13.png: 2302520 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_14.png: 1992004 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_15.png: 1748190 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_16.png: 1517684 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_17.png: 1860744 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_18.png: 2239918 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_19.png: 2189052 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_2.png: 2030676 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_20.png: 2133320 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_21.png: 2025378 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_22.png: 1974576 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_23.png: 2013560 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_24.png: 2252944 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_25.png: 2334409 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_26.png: 1686565 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_27.png: 1780223 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_28.png: 2180432 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_29.png: 1874492 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_3.png: 2026553 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_30.png: 2161102 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_31.png: 2042369 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_32.png: 1808642 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_33.png: 2543064 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_34.png: 2252637 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_35.png: 2346422 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_36.png: 2191575 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_37.png: 1816920 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_38.png: 2314640 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_39.png: 1687490 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_4.png: 2175795 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_40.png: 2130129 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_41.png: 1551721 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_42.png: 1623554 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_43.png: 2305399 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_44.png: 2325187 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_45.png: 2101913 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_46.png: 2196277 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_47.png: 2014769 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_48.png: 2011208 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_49.png: 2041931 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_5.png: 1631079 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_50.png: 2386919 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_51.png: 2335580 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_6.png: 1427949 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_7.png: 2062846 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_8.png: 2579806 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - position_9.png: 2110867 bytes, Type: PNG, Dimensions: (1024, 1024)
#
# Folder_Name: 'shape'
#   Number of images: 74
#   Total size (bytes): 142741856
#
#     - shape_0.png: 2429027 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_1.png: 1806092 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_10.png: 1729147 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_11.png: 2090647 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_12.png: 2952555 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_13.png: 1953740 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_14.png: 2240188 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_15.png: 2474048 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_16.png: 1692945 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_17.png: 2404984 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_18.png: 1865586 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_19.png: 2121075 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_2.png: 2142171 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_20.png: 2392215 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_21.png: 2280392 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_22.png: 1959577 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_23.png: 1369863 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_24.png: 1548703 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_25.png: 1184215 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_26.png: 1546306 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_27.png: 2380862 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_28.png: 1643936 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_29.png: 1910725 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_3.png: 2004998 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_30.png: 1740461 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_31.png: 2213844 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_32.png: 1492698 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_33.png: 1878624 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_34.png: 2182138 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_35.png: 1640451 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_36.png: 1847177 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_37.png: 2661546 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_38.png: 2073357 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_39.png: 1320613 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_4.png: 2044482 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_40.png: 1862289 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_41.png: 878982 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_42.png: 1537941 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_43.png: 1453774 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_44.png: 1823886 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_45.png: 2007013 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_46.png: 1242768 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_47.png: 1861008 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_48.png: 1685571 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_49.png: 1650690 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_5.png: 2111474 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_50.png: 1640322 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_51.png: 2241985 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_52.png: 2428998 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_53.png: 1872969 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_54.png: 2152532 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_55.png: 1597708 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_56.png: 1745602 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_57.png: 2173992 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_58.png: 2254791 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_59.png: 1635693 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_6.png: 2211171 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_60.png: 2112020 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_61.png: 2186064 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_62.png: 1722558 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_63.png: 1959692 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_64.png: 2016570 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_65.png: 1525047 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_66.png: 1730823 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_67.png: 2239709 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_68.png: 1630655 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_69.png: 2031698 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_7.png: 2243970 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_70.png: 2291842 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_71.png: 1805486 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_72.png: 1759078 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_73.png: 1871517 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_8.png: 2176716 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - shape_9.png: 2147864 bytes, Type: PNG, Dimensions: (1024, 1024)
#
# Folder_Name: 'size'
#   Number of images: 106
#   Total size (bytes): 215740871
#
#     - size_0.png: 1627048 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_1.png: 1493418 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_10.png: 1906653 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_100.png: 1910386 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_101.png: 1680291 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_102.png: 1876184 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_103.png: 1835103 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_104.png: 1622767 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_105.png: 1781866 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_11.png: 1208519 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_12.png: 1597166 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_13.png: 1905939 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_14.png: 1863673 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_15.png: 1679495 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_16.png: 2641070 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_17.png: 2330978 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_18.png: 2321024 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_19.png: 2544934 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_2.png: 2159829 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_20.png: 2049832 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_21.png: 2433524 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_22.png: 2211156 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_23.png: 2432282 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_24.png: 2672896 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_25.png: 2452610 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_26.png: 1831931 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_27.png: 2050368 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_28.png: 1631363 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_29.png: 1821551 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_3.png: 1825588 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_30.png: 2052489 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_31.png: 1815467 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_32.png: 2168501 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_33.png: 2398125 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_34.png: 2348349 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_35.png: 2140574 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_36.png: 1829686 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_37.png: 1850126 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_38.png: 1280937 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_39.png: 2268295 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_4.png: 1791555 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_40.png: 1845632 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_41.png: 1588776 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_42.png: 2206268 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_43.png: 2168692 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_44.png: 1839724 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_45.png: 1814873 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_46.png: 1693279 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_47.png: 1556696 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_48.png: 2754973 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_49.png: 2321185 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_5.png: 2074551 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_50.png: 2219481 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_51.png: 2453794 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_52.png: 2028626 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_53.png: 1829038 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_54.png: 1988015 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_55.png: 2152476 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_56.png: 2061733 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_57.png: 2032258 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_58.png: 1930047 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_59.png: 1815179 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_6.png: 2156672 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_60.png: 1672549 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_61.png: 1716567 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_62.png: 2530407 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_63.png: 2479335 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_64.png: 2628138 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_65.png: 2173720 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_66.png: 2486921 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_67.png: 2430420 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_68.png: 2140751 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_69.png: 2470938 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_7.png: 2112008 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_70.png: 1888343 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_71.png: 2180092 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_72.png: 2189140 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_73.png: 1365529 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_74.png: 2156397 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_75.png: 2394671 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_76.png: 2070626 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_77.png: 2954115 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_78.png: 2914580 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_79.png: 2003345 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_8.png: 1887834 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_80.png: 1605751 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_81.png: 2172635 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_82.png: 2308860 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_83.png: 2102105 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_84.png: 1252829 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_85.png: 1553716 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_86.png: 2000600 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_87.png: 1804223 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_88.png: 2061664 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_89.png: 2323798 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_9.png: 1724553 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_90.png: 1803197 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_91.png: 2079029 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_92.png: 2305786 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_93.png: 2075452 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_94.png: 1597737 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_95.png: 1816678 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_96.png: 2148770 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_97.png: 2091118 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_98.png: 2139110 bytes, Type: PNG, Dimensions: (1024, 1024)
#     - size_99.png: 2051318 bytes, Type: PNG, Dimensions: (1024, 1024)

# %%
# to display the images ,need to store the image paths from thh folders 

# Initialize a list to store image paths
image_paths = []

# Iterate through each folder to collect image paths
for folder in folders_list:
    folder_path = os.path.join(dataset_path, folder) 
    
    if os.path.exists(folder_path):
        # Get image files in the folder
        image_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]
        image_paths.extend(image_files)  # Add all image paths to the list

# Create a DataFrame from the image paths
image_df = pd.DataFrame(image_paths, columns=['image_path'])

# %%
# display the images
print(image_df.head(3))
# Out:
#                                           image_path
# 0  C:\Users\Shree\Documents\VisionClarity-Mitigat...
# 1  C:\Users\Shree\Documents\VisionClarity-Mitigat...
# 2  C:\Users\Shree\Documents\VisionClarity-Mitigat...

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os

# Define the image path
image_path = r"C:\Users\Shree\Documents\VisionClarity-Mitigating-Object-Hallucination-in-MLLM-Models\Shree\Images\color\color_1.png"

# Open the image
img = Image.open(image_path)

# Display the image
plt.figure(figsize=(10, 8))
plt.imshow(img)
plt.axis('off')  # Hide the axes
plt.title(os.path.basename(image_path))  # Display the image filename as the title
plt.show()

# %% [markdown]
# # HW2
# ###  option 3 :Pre-trained models

# %%
import os
import torch
from torchvision import models, transforms
from PIL import Image
import matplotlib.pyplot as plt
from transformers import BlipProcessor, BlipForConditionalGeneration
import warnings

# Suppress warnings
warnings.filterwarnings("ignore")

# %%
# Define the transformation for the input image
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize to match the model's expected input size
    transforms.ToTensor(),  # Convert the image to a tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize the image
])

# %%
#Load a pre-trained ResNet model
resnet_model = models.resnet50(pretrained=True)
resnet_model.eval()  # Set the model to evaluation mode
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
# Load the BLIP model and processor for image captioning
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
blip_model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# %%
#Define functions for feature extraction and description generation
def extract_image_features(image_path):
    """Extract image features using ResNet (optional)."""
    img = Image.open(image_path).convert('RGB')
    img_tensor = transform(img).unsqueeze(0)  # Add batch dimension
    with torch.no_grad():
        features = resnet_model(img_tensor)  # Extract features
    return features

def generate_description(image_path):
    """Generate a description for the image using the BLIP model."""
    # Load and process the image
    raw_image = Image.open(image_path).convert('RGB')
    # Preprocess the image
    pixel_values = processor(raw_image, return_tensors="pt").pixel_values

    # Generate description
    output = blip_model.generate(pixel_values)
    description = processor.decode(output[0], skip_special_tokens=True)
    return description

# %%
image_path = r"C:\Users\Shree\Documents\VisionClarity-Mitigating-Object-Hallucination-in-MLLM-Models\Shree\Images\color\color_1.png"  

# Optionally extract features using ResNet
image_features = extract_image_features(image_path)

# Generate description using the BLIP model
description = generate_description(image_path)

# Display the results
print("Generated Description:", description)

# Display the image
img = Image.open(image_path)
plt.imshow(img)
plt.axis('off')
plt.title("Input Image")
plt.show()
# Out:
# Generated Description: a table with a glass and a colorful mosaic

# %% [markdown]
# - The image does not have an accurate description, highlighting the issue of object hallucinations. As we continue to develop the model, we need to fine-tune it to enhance the image descriptions and evaluate it against other models to ensure improvements are effectively achieve.
